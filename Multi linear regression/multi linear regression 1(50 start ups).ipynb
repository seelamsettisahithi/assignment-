# %%
import pandas as pd
import seaborn as sns
from pandas_profiling import ProfileReport

# %%
startups_profile = ProfileReport(startups, title="Pandas Profiling Report", explorative=True)

# %%
startups_profile
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-05-28 08:13:18.943859&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
startups = pd.read_csv("C://data science//data sets//50_Startups.csv")

# %%
startups.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %%
startups.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.pairplot(startups)

# %%
start_up = startup.rename({"R&D Spend": "RDspend","Marketing Spend":"marketingspend"},axis =1)

# %%
start_up.head(5)
# Out:
#      RDspend  Administration  marketingspend       State     Profit
# 0  165349.20       136897.80       471784.10    New York  192261.83
# 1  162597.70       151377.59       443898.53  California  191792.06
# 2  153441.51       101145.55       407934.54     Florida  191050.39
# 3  144372.41       118671.85       383199.62    New York  182901.99
# 4  142107.34        91391.77       366168.42     Florida  166187.94

# %%
import statsmodels.formula.api as smf
model1=smf.ols('marketingspend~RDspend+Profit',data=start_up).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         marketingspend   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.541
# Method:                 Least Squares   F-statistic:                     29.83
# Date:                Fri, 28 May 2021   Prob (F-statistic):           4.33e-09
# Time:                        13:22:08   Log-Likelihood:                -635.66
# No. Observations:                  50   AIC:                             1277.
# Df Residuals:                      47   BIC:                             1283.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5.127e+04   6.62e+04     -0.775      0.442   -1.84e+05    8.19e+04
# ...

# %%
mrd_model=smf.ols('marketingspend~RDspend',data=start_up).fit()
mrd_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         marketingspend   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                     52.95
# Date:                Fri, 28 May 2021   Prob (F-statistic):           2.77e-09
# Time:                        13:22:52   Log-Likelihood:                -637.56
# No. Observations:                  50   AIC:                             1279.
# Df Residuals:                      48   BIC:                             1283.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.878e+04    2.3e+04      2.995      0.004    2.26e+04    1.15e+05
# ...

# %%
mp_model=smf.ols('marketingspend~Profit',data=start_up).fit()
mp_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         marketingspend   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Fri, 28 May 2021   Prob (F-statistic):           4.38e-10
# Time:                        13:23:24   Log-Likelihood:                -635.67
# No. Observations:                  50   AIC:                             1275.
# Df Residuals:                      48   BIC:                             1279.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -4.31e+04   3.46e+04     -1.247      0.219   -1.13e+05    2.64e+04
# ...

# %%
rsq_hp=smf.ols('RDspend~Administration+marketingspend+Profit',data=start_up).fit().rsquared
vif_hp = 1/(1-rsq_hp) # 16.33

# %%
rsq_hp
# Out:
# 0.9488830971212534

# %%
vif_hp
# Out:
# 19.563000566996017

# %%
rsq_wt = smf.ols('Profit~RDspend+marketingspend+Administration',data=start_up).fit().rsquared
vif_wt = 1/(1-rsq_wt) # 564.9

# %%
rsq_wt
# Out:
# 0.9507459940683246

# %%
vif_wt
# Out:
# 20.30291711474573

# %%
rsq_vol = smf.ols('marketingspend~Profit+Administration+RDspend',data=start_up).fit().rsquared  
vif_vol = 1/(1-rsq_vol) #  564.84

# %%
rsq_vol
# Out:
# 0.5943750647160794

# %%
vif_vol
# Out:
# 2.4653316722258247

# %%
rsq_sp = smf.ols('Administration~Profit+marketingspend+RDspend',data=start_up).fit().rsquared  
vif_sp = 1/(1-rsq_sp) #  16.35

# %%
rsq_sp
# Out:
# 0.15408049296399062

# %%
vif_sp
# Out:
# 1.1821455725780203

# %%
d1 = {'Variables':['RDspend','Profit','marketingspend','Administration'],'VIF':[vif_hp,vif_wt,vif_vol,vif_sp]}
Vif_frame = pd.DataFrame(d1)
Vif_frame
# Out:
#         Variables        VIF
# 0         RDspend  19.563001
# 1          Profit  20.302917
# 2  marketingspend   2.465332
# 3  Administration   1.182146

# %%
import statsmodels.api as sm
sm.graphics.influence_plot(model1)

# %%
startup_new=start_up.drop(start_up.index[[49]],axis=0)

# %%
startup_new
# Out:
#       RDspend  Administration  marketingspend       State     Profit
# 0   165349.20       136897.80       471784.10    New York  192261.83
# 1   162597.70       151377.59       443898.53  California  191792.06
# 2   153441.51       101145.55       407934.54     Florida  191050.39
# 3   144372.41       118671.85       383199.62    New York  182901.99
# 4   142107.34        91391.77       366168.42     Florida  166187.94
# 5   131876.90        99814.71       362861.36    New York  156991.12
# 6   134615.46       147198.87       127716.82  California  156122.51
# 7   130298.13       145530.06       323876.68     Florida  155752.60
# 8   120542.52       148718.95       311613.29    New York  152211.77
# 9   123334.88       108679.17       304981.62  California  149759.96
# 10  101913.08       110594.11       229160.95     Florida  146121.95
# 11  100671.96        91790.61       249744.55  California  144259.40
# 12   93863.75       127320.38       249839.44     Florida  141585.52
# ...

# %%
model2=smf.ols('marketingspend~RDspend+Profit',data=startup_new).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         marketingspend   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.530
# Method:                 Least Squares   F-statistic:                     28.09
# Date:                Fri, 28 May 2021   Prob (F-statistic):           1.07e-08
# Time:                        13:32:34   Log-Likelihood:                -623.01
# No. Observations:                  49   AIC:                             1252.
# Df Residuals:                      46   BIC:                             1258.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -9.486e+04    8.2e+04     -1.157      0.253    -2.6e+05    7.02e+04
# ...

# %%
sm.graphics.plot_partregress_grid(model1)

# %%
final_ml=smf.ols('marketingspend~RDspend',data=start_up).fit()
final_ml.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         marketingspend   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                     52.95
# Date:                Fri, 28 May 2021   Prob (F-statistic):           2.77e-09
# Time:                        13:33:34   Log-Likelihood:                -637.56
# No. Observations:                  50   AIC:                             1279.
# Df Residuals:                      48   BIC:                             1283.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.878e+04    2.3e+04      2.995      0.004    2.26e+04    1.15e+05
# ...

# %%
sm.graphics.plot_partregress_grid(final_ml)

# %%
mpg_pred=final_ml.predict(startup_new)

# %%
import matplotlib.pyplot as plt
plt.scatter(startup_new.marketingspend,mpg_pred,c="r");plt.xlabel("observed_values");plt.ylabel("fitted_values")
# Out:
# Text(0, 0.5, 'fitted_values')
